# %% [markdown]
# # Flash Flood Prediction - Model Training & Evaluation Notebook
# Comparison of Ensemble Machine Learning Regressors on Multi-Source Hydrological Data.

# %%
from src.pipeline.train_pipeline import TrainPipeline
pipeline = TrainPipeline()
metrics = pipeline.run_pipeline()
print('Pipeline Execution Results:')
print(metrics)
